# %% [markdown]
# <a href="https://colab.research.google.com/github/DOL-DOM/2022_cau_oss_hackathon/blob/main/hackathon_team10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteVHQQ96/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteVHQQ96/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incomplete9G6P4W/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incomplete9G6P4W/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete8EE6DL/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete8EE6DL/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train / 255
x_test_after = x_test / 255

# %% [markdown]
# # **3. 모델 생성**

# %%
drop_rate = 0.3
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

# Flatten layer: 28 x 28 x 1 image를 1D vector input으로 변환
model.add(keras.layers.Flatten(input_shape=input_shape))

# 1st hidden layer: fully-connected layer
model.add(keras.layers.Dense(1024, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))

# 2nd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(512, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))

# 3rd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(256, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))

# 4th hidden layer: fully-connected layer 
model.add(keras.layers.Dense(128, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))



# Output layer: fully-connected layer 
model.add(keras.layers.Dense(num_classes, activation=tf.nn.softmax))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')



# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))

model.summary()
# Out:
# Epoch 1/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.6688 - accuracy: 0.8004
# Epoch 1: val_accuracy improved from -inf to 0.80895, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.6672 - accuracy: 0.8008 - val_loss: 0.6279 - val_accuracy: 0.8090
# Epoch 2/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.3766 - accuracy: 0.8809
# Epoch 2: val_accuracy improved from 0.80895 to 0.81255, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.3766 - accuracy: 0.8809 - val_loss: 0.6401 - val_accuracy: 0.8126
# Epoch 3/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.3197 - accuracy: 0.8970
# Epoch 3: val_accuracy improved from 0.81255 to 0.82028, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3197 - accuracy: 0.8970 - val_loss: 0.6280 - val_accuracy: 0.8203
# Epoch 4/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9044
# Epoch 4: val_accuracy improved from 0.82028 to 0.82702, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2914 - accuracy: 0.9044 - val_loss: 0.6270 - val_accuracy: 0.8270
# Epoch 5/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.9097
# Epoch 5: val_accuracy did not improve from 0.82702
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2719 - accuracy: 0.9098 - val_loss: 0.6604 - val_accuracy: 0.8238
# Epoch 6/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.2564 - accuracy: 0.9140
# Epoch 6: val_accuracy did not improve from 0.82702
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2565 - accuracy: 0.9140 - val_loss: 0.6552 - val_accuracy: 0.8251
# Epoch 7/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.2459 - accuracy: 0.9173
# Epoch 7: val_accuracy improved from 0.82702 to 0.83227, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2461 - accuracy: 0.9173 - val_loss: 0.6151 - val_accuracy: 0.8323
# Epoch 8/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.9203
# Epoch 8: val_accuracy did not improve from 0.83227
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2378 - accuracy: 0.9203 - val_loss: 0.6667 - val_accuracy: 0.8317
# Epoch 9/100
# 1392/1407 [============================>.] - ETA: 0s - loss: 0.2287 - accuracy: 0.9227
# Epoch 9: val_accuracy did not improve from 0.83227
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2288 - accuracy: 0.9227 - val_loss: 0.6730 - val_accuracy: 0.8270
# Epoch 10/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9238
# Epoch 10: val_accuracy improved from 0.83227 to 0.83675, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2227 - accuracy: 0.9238 - val_loss: 0.6533 - val_accuracy: 0.8367
# Epoch 11/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9257
# Epoch 11: val_accuracy did not improve from 0.83675
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2164 - accuracy: 0.9257 - val_loss: 0.7549 - val_accuracy: 0.8241
# Epoch 12/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9273
# Epoch 12: val_accuracy did not improve from 0.83675
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2131 - accuracy: 0.9273 - val_loss: 0.7243 - val_accuracy: 0.8306
# Epoch 13/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.2095 - accuracy: 0.9288
# Epoch 13: val_accuracy improved from 0.83675 to 0.83777, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2093 - accuracy: 0.9289 - val_loss: 0.6885 - val_accuracy: 0.8378
# Epoch 14/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9289
# Epoch 14: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.2065 - accuracy: 0.9289 - val_loss: 0.7291 - val_accuracy: 0.8329
# Epoch 15/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9307
# Epoch 15: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2034 - accuracy: 0.9307 - val_loss: 0.7112 - val_accuracy: 0.8360
# Epoch 16/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9321
# Epoch 16: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1965 - accuracy: 0.9321 - val_loss: 0.7577 - val_accuracy: 0.8321
# Epoch 17/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9318
# Epoch 17: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1966 - accuracy: 0.9318 - val_loss: 0.7565 - val_accuracy: 0.8300
# Epoch 18/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1924 - accuracy: 0.9338
# Epoch 18: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1925 - accuracy: 0.9337 - val_loss: 0.7388 - val_accuracy: 0.8353
# Epoch 19/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1907 - accuracy: 0.9342
# Epoch 19: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1906 - accuracy: 0.9342 - val_loss: 0.7897 - val_accuracy: 0.8318
# Epoch 20/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.9348
# Epoch 20: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1880 - accuracy: 0.9347 - val_loss: 0.8296 - val_accuracy: 0.8260
# Epoch 21/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1856 - accuracy: 0.9361
# Epoch 21: val_accuracy did not improve from 0.83777
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1854 - accuracy: 0.9362 - val_loss: 0.7629 - val_accuracy: 0.8352
# Epoch 22/100
# 1391/1407 [============================>.] - ETA: 0s - loss: 0.1831 - accuracy: 0.9369
# Epoch 22: val_accuracy improved from 0.83777 to 0.83968, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1829 - accuracy: 0.9370 - val_loss: 0.7403 - val_accuracy: 0.8397
# Epoch 23/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1836 - accuracy: 0.9368
# Epoch 23: val_accuracy improved from 0.83968 to 0.84032, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1839 - accuracy: 0.9367 - val_loss: 0.7268 - val_accuracy: 0.8403
# Epoch 24/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1797 - accuracy: 0.9375
# Epoch 24: val_accuracy improved from 0.84032 to 0.84115, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1797 - accuracy: 0.9375 - val_loss: 0.7341 - val_accuracy: 0.8411
# Epoch 25/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1775 - accuracy: 0.9386
# Epoch 25: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1778 - accuracy: 0.9385 - val_loss: 0.7996 - val_accuracy: 0.8350
# Epoch 26/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1790 - accuracy: 0.9375
# Epoch 26: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1790 - accuracy: 0.9375 - val_loss: 0.9188 - val_accuracy: 0.8241
# Epoch 27/100
# 1393/1407 [============================>.] - ETA: 0s - loss: 0.1759 - accuracy: 0.9390
# Epoch 27: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1758 - accuracy: 0.9390 - val_loss: 0.8639 - val_accuracy: 0.8330
# Epoch 28/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9393
# Epoch 28: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1749 - accuracy: 0.9393 - val_loss: 0.8494 - val_accuracy: 0.8329
# Epoch 29/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.9399
# Epoch 29: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1726 - accuracy: 0.9399 - val_loss: 0.9043 - val_accuracy: 0.8299
# Epoch 30/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1718 - accuracy: 0.9405
# Epoch 30: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1718 - accuracy: 0.9405 - val_loss: 0.8732 - val_accuracy: 0.8362
# Epoch 31/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1690 - accuracy: 0.9406
# Epoch 31: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1689 - accuracy: 0.9406 - val_loss: 0.8470 - val_accuracy: 0.8329
# Epoch 32/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1678 - accuracy: 0.9410
# Epoch 32: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1678 - accuracy: 0.9411 - val_loss: 0.9550 - val_accuracy: 0.8296
# Epoch 33/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.9410
# Epoch 33: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1694 - accuracy: 0.9410 - val_loss: 0.8829 - val_accuracy: 0.8370
# Epoch 34/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9424
# Epoch 34: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1669 - accuracy: 0.9424 - val_loss: 0.8813 - val_accuracy: 0.8322
# Epoch 35/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9424
# Epoch 35: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1655 - accuracy: 0.9424 - val_loss: 0.8624 - val_accuracy: 0.8400
# Epoch 36/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.9430
# Epoch 36: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1649 - accuracy: 0.9430 - val_loss: 0.9841 - val_accuracy: 0.8346
# Epoch 37/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1633 - accuracy: 0.9429
# Epoch 37: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1632 - accuracy: 0.9429 - val_loss: 0.9867 - val_accuracy: 0.8342
# Epoch 38/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1628 - accuracy: 0.9424
# Epoch 38: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1628 - accuracy: 0.9424 - val_loss: 0.9902 - val_accuracy: 0.8309
# Epoch 39/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1616 - accuracy: 0.9434
# Epoch 39: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1615 - accuracy: 0.9434 - val_loss: 0.9505 - val_accuracy: 0.8361
# Epoch 40/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1593 - accuracy: 0.9438
# Epoch 40: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1592 - accuracy: 0.9438 - val_loss: 0.9478 - val_accuracy: 0.8343
# Epoch 41/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1593 - accuracy: 0.9448
# Epoch 41: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1593 - accuracy: 0.9449 - val_loss: 0.9963 - val_accuracy: 0.8340
# Epoch 42/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1603 - accuracy: 0.9444
# Epoch 42: val_accuracy did not improve from 0.84115
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1602 - accuracy: 0.9444 - val_loss: 0.9786 - val_accuracy: 0.8339
# Epoch 43/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1589 - accuracy: 0.9442
# Epoch 43: val_accuracy improved from 0.84115 to 0.84480, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1589 - accuracy: 0.9442 - val_loss: 0.8859 - val_accuracy: 0.8448
# Epoch 44/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1574 - accuracy: 0.9451
# Epoch 44: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1574 - accuracy: 0.9451 - val_loss: 1.0949 - val_accuracy: 0.8306
# Epoch 45/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9452
# Epoch 45: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1570 - accuracy: 0.9452 - val_loss: 1.0416 - val_accuracy: 0.8324
# Epoch 46/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1552 - accuracy: 0.9455
# Epoch 46: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1552 - accuracy: 0.9455 - val_loss: 1.1262 - val_accuracy: 0.8270
# Epoch 47/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.1549 - accuracy: 0.9458
# Epoch 47: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1552 - accuracy: 0.9458 - val_loss: 1.0481 - val_accuracy: 0.8284
# Epoch 48/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1541 - accuracy: 0.9463
# Epoch 48: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1542 - accuracy: 0.9463 - val_loss: 1.0133 - val_accuracy: 0.8283
# Epoch 49/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9464
# Epoch 49: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1528 - accuracy: 0.9464 - val_loss: 1.0079 - val_accuracy: 0.8306
# Epoch 50/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1520 - accuracy: 0.9465
# Epoch 50: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1520 - accuracy: 0.9465 - val_loss: 0.9992 - val_accuracy: 0.8328
# Epoch 51/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9465
# Epoch 51: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1529 - accuracy: 0.9466 - val_loss: 1.1561 - val_accuracy: 0.8302
# Epoch 52/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1530 - accuracy: 0.9468
# Epoch 52: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1531 - accuracy: 0.9468 - val_loss: 1.0916 - val_accuracy: 0.8333
# Epoch 53/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.1507 - accuracy: 0.9475
# Epoch 53: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1504 - accuracy: 0.9476 - val_loss: 1.1497 - val_accuracy: 0.8273
# Epoch 54/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1492 - accuracy: 0.9481
# Epoch 54: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1492 - accuracy: 0.9481 - val_loss: 1.1425 - val_accuracy: 0.8275
# Epoch 55/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1488 - accuracy: 0.9476
# Epoch 55: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1489 - accuracy: 0.9477 - val_loss: 1.0463 - val_accuracy: 0.8392
# Epoch 56/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9481
# Epoch 56: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1468 - accuracy: 0.9481 - val_loss: 1.1984 - val_accuracy: 0.8306
# Epoch 57/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9482
# Epoch 57: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1483 - accuracy: 0.9483 - val_loss: 1.0919 - val_accuracy: 0.8371
# Epoch 58/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1467 - accuracy: 0.9485
# Epoch 58: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1467 - accuracy: 0.9485 - val_loss: 1.1660 - val_accuracy: 0.8321
# Epoch 59/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9483
# Epoch 59: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1457 - accuracy: 0.9483 - val_loss: 1.1286 - val_accuracy: 0.8316
# Epoch 60/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9488
# Epoch 60: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1463 - accuracy: 0.9488 - val_loss: 1.1100 - val_accuracy: 0.8304
# Epoch 61/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1469 - accuracy: 0.9489
# Epoch 61: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1469 - accuracy: 0.9489 - val_loss: 1.0986 - val_accuracy: 0.8347
# Epoch 62/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1464 - accuracy: 0.9485
# Epoch 62: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1465 - accuracy: 0.9485 - val_loss: 1.1230 - val_accuracy: 0.8339
# Epoch 63/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9485
# Epoch 63: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1453 - accuracy: 0.9485 - val_loss: 1.2872 - val_accuracy: 0.8234
# Epoch 64/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9485
# Epoch 64: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1462 - accuracy: 0.9485 - val_loss: 1.2693 - val_accuracy: 0.8316
# Epoch 65/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9494
# Epoch 65: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1451 - accuracy: 0.9494 - val_loss: 1.2082 - val_accuracy: 0.8285
# Epoch 66/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9504
# Epoch 66: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1423 - accuracy: 0.9504 - val_loss: 1.0614 - val_accuracy: 0.8365
# Epoch 67/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9500
# Epoch 67: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1424 - accuracy: 0.9499 - val_loss: 1.1961 - val_accuracy: 0.8372
# Epoch 68/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9503
# Epoch 68: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1416 - accuracy: 0.9503 - val_loss: 1.1933 - val_accuracy: 0.8346
# Epoch 69/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9507
# Epoch 69: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1414 - accuracy: 0.9507 - val_loss: 1.1728 - val_accuracy: 0.8380
# Epoch 70/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9504
# Epoch 70: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1418 - accuracy: 0.9504 - val_loss: 1.1807 - val_accuracy: 0.8327
# Epoch 71/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9501
# Epoch 71: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1411 - accuracy: 0.9501 - val_loss: 1.1867 - val_accuracy: 0.8337
# Epoch 72/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1395 - accuracy: 0.9512
# Epoch 72: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1396 - accuracy: 0.9512 - val_loss: 1.2172 - val_accuracy: 0.8292
# Epoch 73/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1381 - accuracy: 0.9517
# Epoch 73: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1380 - accuracy: 0.9517 - val_loss: 1.2074 - val_accuracy: 0.8293
# Epoch 74/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9508
# Epoch 74: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1402 - accuracy: 0.9508 - val_loss: 1.0841 - val_accuracy: 0.8361
# Epoch 75/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1406 - accuracy: 0.9504
# Epoch 75: val_accuracy did not improve from 0.84480
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1406 - accuracy: 0.9504 - val_loss: 1.2472 - val_accuracy: 0.8318
# Epoch 76/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1395 - accuracy: 0.9512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-bf7a75e9b312> in <module>
#      44 # shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
#      45 # validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
# ---> 46 model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))
#      47
#      48 model.summary()
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1429               use_multiprocessing=use_multiprocessing,
#    1430               return_dict=True,
# -> 1431               _use_cached_eval_dataset=True)
#    1432           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team10'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team10'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.7518 - accuracy: 0.8617
# [0.7517508268356323, 0.8616750240325928]
